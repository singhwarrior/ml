# %%
import pandas as pd
import yaml
import glob

# %% [markdown]
# ### Reading the data from https://cricsheet.org/ which I have downloaded as odis

# %%
path = r'odis' # use your path
allFiles = glob.glob(path + "/*.yaml")

dfs = []

columns = ['info.teams','info.overs','info.match_type']
cities = ['HYDERABAD', 'NAGPUR', 'RANCHI', 'MOHALI', 'DELHI']

for file_ in allFiles:
    #print(file_)
    with open(file_, 'r') as f:
        df = pd.io.json.json_normalize(yaml.load(f))
        if 'info.city' in df:
            df['team1'] = df['info.teams'].apply(lambda teams : teams[0].upper()) 
            df['team2'] = df['info.teams'].apply(lambda teams : teams[1].upper())
            df = df[df['team1'].isin(['INDIA','AUSTRALIA']) & df['team2'].isin(['INDIA','AUSTRALIA'])]
            df['info.city'] = df['info.city'].apply(lambda city : city.upper())
            df = df[df['info.city'].isin(cities)]
            df = df.drop(columns,1)
            df = df[df['info.gender'] == 'male']
            dfs.append(df)

frame = pd.concat(dfs, axis = 0, ignore_index = True)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:35: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False

# %%
frame.head()
frame.shape
#df['team1']
# Out:
# (7, 28)

# %% [markdown]
# ### Raw DataFrame : Without Cleanup

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 28 columns):
# info.city                      7 non-null object
# info.dates                     7 non-null object
# info.gender                    7 non-null object
# info.neutral_venue             0 non-null float64
# info.outcome.by.runs           4 non-null float64
# info.outcome.by.wickets        2 non-null float64
# info.outcome.method            0 non-null object
# info.outcome.result            1 non-null object
# info.outcome.winner            6 non-null object
# info.player_of_match           6 non-null object
# info.supersubs.Australia       0 non-null object
# info.supersubs.Bangladesh      0 non-null object
# info.supersubs.India           0 non-null object
# info.supersubs.New Zealand     0 non-null object
# info.supersubs.Pakistan        0 non-null object
# info.supersubs.South Africa    0 non-null object
# info.supersubs.Sri Lanka       0 non-null object
# info.supersubs.West Indies     0 non-null object
# info.toss.decision             7 non-null object
# info.toss.winner               7 non-null object
# info.umpires                   7 non-null object
# info.venue                     7 non-null object
# innings                        7 non-null object
# meta.created                   7 non-null object
# meta.data_version              7 non-null float64
# meta.revision                  7 non-null int64
# team1                          7 non-null object
# team2                          7 non-null object
# dtypes: float64(4), int64(1), object(23)
# memory usage: 1.6+ KB

# %% [markdown]
# ### Cleaning data : Removing Columns which are not required

# %%
columns_not_required = ['info.supersubs.Australia','info.supersubs.Bangladesh','info.supersubs.India'
                        ,'info.supersubs.New Zealand', 'info.supersubs.Pakistan', 'info.supersubs.South Africa',
                       'info.supersubs.Sri Lanka', 'info.supersubs.West Indies', 'meta.created', 'meta.data_version',
                       'meta.revision','info.neutral_venue','info.neutral_venue','info.outcome.method','info.gender']
frame = frame.drop(columns_not_required,1)

# %% [markdown]
# ### DataFrame after cleanup

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 14 columns):
# info.city                  7 non-null object
# info.dates                 7 non-null object
# info.outcome.by.runs       4 non-null float64
# info.outcome.by.wickets    2 non-null float64
# info.outcome.result        1 non-null object
# info.outcome.winner        6 non-null object
# info.player_of_match       6 non-null object
# info.toss.decision         7 non-null object
# info.toss.winner           7 non-null object
# info.umpires               7 non-null object
# info.venue                 7 non-null object
# innings                    7 non-null object
# team1                      7 non-null object
# team2                      7 non-null object
# dtypes: float64(2), object(12)
# memory usage: 864.0+ bytes

# %% [markdown]
# ### Solution Starts from here

# %%
frame
# Out:
#    info.city    info.dates  info.outcome.by.runs  info.outcome.by.wickets  \
# 0  HYDERABAD  [2009-11-05]                   3.0                      NaN
# 1     NAGPUR  [2009-10-28]                  99.0                      NaN
# 2     NAGPUR  [2007-10-14]                  18.0                      NaN
# 3  HYDERABAD  [2007-10-05]                  47.0                      NaN
# 4     NAGPUR  [2013-10-30]                   NaN                      6.0
# 5     RANCHI  [2013-10-23]                   NaN                      NaN
# 6      DELHI  [2009-10-31]                   NaN                      6.0
#
#   info.outcome.result info.outcome.winner info.player_of_match  \
# 0                 NaN           Australia       [SR Tendulkar]
# 1                 NaN               India           [MS Dhoni]
# 2                 NaN           Australia          [A Symonds]
# 3                 NaN           Australia          [A Symonds]
# 4                 NaN               India            [V Kohli]
# 5           no result                 NaN                  NaN
# 6                 NaN               India       [Yuvraj Singh]
#
#   info.toss.decision info.toss.winner                     info.umpires  \
# 0                bat        Australia      [EAR de Silva, SK Tarapore]
# 1              field        Australia         [AM Saheba, SK Tarapore]
# 2                bat        Australia           [Aleem Dar, AM Saheba]
# 3                bat        Australia         [SA Bucknor, SL Shastri]
# 4              field            India               [NJ Llong, S Ravi]
# 5              field            India  [RA Kettleborough, VA Kulkarni]
# 6                bat        Australia           [SS Hazare, AM Saheba]
#
#                                      info.venue  \
# 0     Rajiv Gandhi International Stadium, Uppal
# 1  Vidarbha Cricket Association Stadium, Jamtha
# 2           Vidarbha Cricket Association Ground
# 3     Rajiv Gandhi International Stadium, Uppal
# 4  Vidarbha Cricket Association Stadium, Jamtha
# 5            JSCA International Stadium Complex
# 6                              Feroz Shah Kotla
#
#                                              innings  team1      team2
# 0  [{'1st innings': {'team': 'Australia', 'delive...  INDIA  AUSTRALIA
# 1  [{'1st innings': {'team': 'India', 'deliveries...  INDIA  AUSTRALIA
# 2  [{'1st innings': {'team': 'Australia', 'delive...  INDIA  AUSTRALIA
# 3  [{'1st innings': {'team': 'Australia', 'delive...  INDIA  AUSTRALIA
# 4  [{'1st innings': {'team': 'Australia', 'delive...  INDIA  AUSTRALIA
# 5  [{'1st innings': {'team': 'Australia', 'delive...  INDIA  AUSTRALIA
# 6  [{'1st innings': {'team': 'Australia', 'delive...  INDIA  AUSTRALIA

# %% [markdown]
# ### From above DataFrame we can first conclude following
# - Hyderabad there are two matches in both Australia wins => **Chances of Australia to win in Hyderabad**
# - Nagpur there are three macthes and two won by India and 1 won by Australia => **Chances of India to win in Nagpur**
# - Delhi one match and India won => **Chances of India to win in Delhi**
# - Ranchi there was no result i.e. it was draw => **So 50-50 chances of both India and Australia in Ranchi**
# - Mohali no data => **So 50-50 chances of both India and Australia in Mohali**

# %% [markdown]
# ## Problem Statement\[1.\] Winner of the series: India will be winner of Series

# %% [markdown]
# ## Problem Statement\[2.\] Series output : India will win 4 matches and Australia will win 1 match

# %% [markdown]
# #### For highest run scorer, wicket taker and sixes first getting the exploded data from INNINGS column of dataframe

# %%
def getBatsmanAndBowler(in_frame):
    in_frame.innings[0][0]['1st innings']['team']
    innings1_batsman = {'batsman':[], 'runs':[], 'sixes':[]}
    innings1_bowler = {'bowler':[], 'wickets':[]}
    in_frame.innings[0][0]['1st innings']['deliveries']
    
    for inning in in_frame.innings:
        for delivery in inning[0]['1st innings']['deliveries']:
            for k,v in delivery.items():
                #print(str(k)+" "+str(v))
                batsman = v['batsman']
                bowler = v['bowler']
                batsman_run = v['runs']['batsman']
                if batsman in innings1_batsman['batsman']:
                    innings1_batsman['runs'][innings1_batsman['batsman'].index(batsman)] = innings1_batsman['runs'][innings1_batsman['batsman'].index(batsman)]+batsman_run
                    if batsman_run == 6:
                        innings1_batsman['sixes'][innings1_batsman['batsman'].index(batsman)] = innings1_batsman['sixes'][innings1_batsman['batsman'].index(batsman)]+1
                else:    
                    innings1_batsman['batsman'].append(batsman)
                    innings1_batsman['runs'].append(batsman_run)
                    if batsman_run == 6:
                        innings1_batsman['sixes'].append(1) 
                    else:
                        innings1_batsman['sixes'].append(0)
            
                if bowler in innings1_bowler['bowler']:
                    if 'wicket' in v:
                        innings1_bowler['wickets'][innings1_bowler['bowler'].index(bowler)] = innings1_bowler['wickets'][innings1_bowler['bowler'].index(bowler)]+1
                else:
                    innings1_bowler['bowler'].append(bowler)
                    if 'wicket' in v:
                        innings1_bowler['wickets'].append(1)
                    else:
                        innings1_bowler['wickets'].append(0)
                        
        for delivery in inning[1]['2nd innings']['deliveries']:
            for k,v in delivery.items():
                #print(str(k)+" "+str(v))
                batsman = v['batsman']
                bowler = v['bowler']
                batsman_run = v['runs']['batsman']
                if batsman in innings1_batsman['batsman']:
                    innings1_batsman['runs'][innings1_batsman['batsman'].index(batsman)] = innings1_batsman['runs'][innings1_batsman['batsman'].index(batsman)]+batsman_run
                    if batsman_run == 6:
                        innings1_batsman['sixes'][innings1_batsman['batsman'].index(batsman)] = innings1_batsman['sixes'][innings1_batsman['batsman'].index(batsman)]+1
                else:    
                    innings1_batsman['batsman'].append(batsman)
                    innings1_batsman['runs'].append(batsman_run)
                    if batsman_run == 6:
                        innings1_batsman['sixes'].append(1) 
                    else:
                        innings1_batsman['sixes'].append(0)
            
                if bowler in innings1_bowler['bowler']:
                    if 'wicket' in v:
                        innings1_bowler['wickets'][innings1_bowler['bowler'].index(bowler)] = innings1_bowler['wickets'][innings1_bowler['bowler'].index(bowler)]+1
                else:
                    innings1_bowler['bowler'].append(bowler)
                    if 'wicket' in v:
                        innings1_bowler['wickets'].append(1)
                    else:
                        innings1_bowler['wickets'].append(0) 
    
    print(innings1_batsman)
    print(innings1_bowler)
    return (innings1_batsman,innings1_bowler)

# %% [markdown]
# #### Creating Dataframe for batsman with runs and sixes, named as batsman_df
# #### Creating Dataframe for bowlers with wickets, named as bowler_df

# %%
output = getBatsmanAndBowler(frame)
batsman_df = pd.DataFrame.from_dict(output[0])
bowler_df = pd.DataFrame.from_dict(output[1])
# Out:
# {'batsman': ['SR Watson', 'SE Marsh', 'RT Ponting', 'CL White', 'MEK Hussey', 'V Sehwag', 'SR Tendulkar', 'G Gambhir', 'Yuvraj Singh', 'MS Dhoni', 'SK Raina', 'Harbhajan Singh', 'RA Jadeja', 'P Kumar', 'A Nehra', 'MM Patel', 'TD Paine', 'AC Voges', 'MG Johnson', 'NM Hauritz', 'PM Siddle', 'BW Hilfenhaus', 'AC Gilchrist', 'MJ Clarke', 'BJ Hodge', 'A Symonds', 'BJ Haddin', 'JR Hopes', 'B Lee', 'SC Ganguly', 'IK Pathan', 'R Dravid', 'RV Uthappa', 'Z Khan', 'ML Hayden', 'RG Sharma', 'S Sreesanth', 'PJ Hughes', 'AJ Finch', 'GJ Bailey', 'GJ Maxwell', 'S Dhawan', 'V Kohli', 'JP Faulkner', 'CJ McKay', 'MC Henriques'], 'runs': [269, 133, 190, 80, 165, 89, 326, 96, 237, 285, 146, 26, 23, 10, 1, 2, 8, 104, 56, 30, 3, 16, 80, 59, 23, 196, 28, 50, 17, 86, 32, 7, 44, 6, 60, 89, 1, 24, 25, 254, 101, 114, 115, 23, 7, 12], 'sixes': [6, 3, 2, 5, 3, 2, 5, 0, 6, 4, 4, 1, 0, 1, 0, 0, 0, 0, 3, 0, 0, 0, 0, 0, 0, 9, 1, 0, 1, 2, 2, 0, 2, 0, 0, 3, 0, 0, 0, 9, 5, 0, 1, 0, 0, 0]}
# {'bowler': ['P Kumar', 'A Nehra', 'MM Patel', 'RA Jadeja', 'Harbhajan Singh', 'Yuvraj Singh', 'BW Hilfenhaus', 'DE Bollinger', 'CJ McKay', 'SR Watson', 'NM Hauritz', 'AC Voges', 'MEK Hussey', 'PM Siddle', 'MG Johnson', 'I Sharma', 'SK Raina', 'Z Khan', 'S Sreesanth', 'IK Pathan', 'M Kartik', 'SR Tendulkar', 'B Lee', 'NW Bracken', 'JR Hopes', 'A Symonds', 'GB Hogg', 'MJ Clarke', 'SR Clark', 'BJ Hodge', 'B Kumar', 'Mohammed Shami', 'R Ashwin', 'A Mishra', 'V Kohli', 'JP Faulkner', 'XJ Doherty', 'GJ Maxwell', 'AJ Finch', 'JD Unadkat', 'R Vinay Kumar', 'MC Henriques'], 'wickets': [4, 2, 0, 9, 4, 2, 2, 1, 4, 4, 1, 0, 0, 2, 11, 2, 1, 6, 3, 3, 1, 0, 3, 0, 2, 0, 7, 0, 1, 0, 1, 4, 4, 0, 0, 1, 0, 0, 1, 0, 2, 2]}

# %% [markdown]
# ## Problem Statement\[3.\] Highest Run Scorer: MS Dhoni (Shown below)
# #### Because SR Tendulkar doesn't play now

# %%
batsman_df
batsman_df.sort_values('runs', ascending=False).head(20)
# Out:
#          batsman  runs  sixes
# 6   SR Tendulkar   326      5
# 9       MS Dhoni   285      4
# 0      SR Watson   269      6
# 39     GJ Bailey   254      9
# 8   Yuvraj Singh   237      6
# 25     A Symonds   196      9
# 2     RT Ponting   190      2
# 4     MEK Hussey   165      3
# 10      SK Raina   146      4
# 1       SE Marsh   133      3
# 42       V Kohli   115      1
# 41      S Dhawan   114      0
# 17      AC Voges   104      0
# 40    GJ Maxwell   101      5
# 7      G Gambhir    96      0
# 5       V Sehwag    89      2
# 35     RG Sharma    89      3
# 29    SC Ganguly    86      2
# 22  AC Gilchrist    80      0
# 3       CL White    80      5

# %% [markdown]
# ## Problem Statement\[4.\] Maximum Sixes: GJ Maxwell (Shown below)
# #### Other playes who hit more sixes are retired now

# %%
batsman_df.sort_values('sixes', ascending=False).head(20)
# Out:
#          batsman  runs  sixes
# 25     A Symonds   196      9
# 39     GJ Bailey   254      9
# 0      SR Watson   269      6
# 8   Yuvraj Singh   237      6
# 3       CL White    80      5
# 6   SR Tendulkar   326      5
# 40    GJ Maxwell   101      5
# 9       MS Dhoni   285      4
# 10      SK Raina   146      4
# 4     MEK Hussey   165      3
# 1       SE Marsh   133      3
# 35     RG Sharma    89      3
# 18    MG Johnson    56      3
# 32    RV Uthappa    44      2
# 29    SC Ganguly    86      2
# 30     IK Pathan    32      2
# 5       V Sehwag    89      2
# 2     RT Ponting   190      2
# 42       V Kohli   115      1
# 13       P Kumar    10      1

# %% [markdown]
# ## Problem Statement\[5.\] Highest Wicket Taker: RA Jadeja (Shown below)
# #### MG Johnson retired now

# %%
bowler_df
bowler_df.sort_values('wickets', ascending=False).head(20)
# Out:
#              bowler  wickets
# 14       MG Johnson       11
# 3         RA Jadeja        9
# 26          GB Hogg        7
# 17           Z Khan        6
# 0           P Kumar        4
# 4   Harbhajan Singh        4
# 32         R Ashwin        4
# 31   Mohammed Shami        4
# 8          CJ McKay        4
# 9         SR Watson        4
# 22            B Lee        3
# 19        IK Pathan        3
# 18      S Sreesanth        3
# 40    R Vinay Kumar        2
# 24         JR Hopes        2
# 1           A Nehra        2
# 41     MC Henriques        2
# 13        PM Siddle        2
# 5      Yuvraj Singh        2
# 6     BW Hilfenhaus        2

# %%
frame.innings[0][1]
# Out:
# {'2nd innings': {'team': 'India',
#   'deliveries': [{0.1: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {0.2: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {0.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {1.1: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {1.2: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'extras': {'wides': 1},
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {1.3: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {1.4: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {1.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {1.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {1.7: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {2.1: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'extras': {'wides': 1},
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {2.2: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {2.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {2.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {2.5: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {2.6: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {2.7: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {3.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {3.2: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {3.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {3.4: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {3.5: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {3.6: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {4.1: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {4.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {4.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {4.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {4.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {4.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#    {5.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {5.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {5.3: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {5.4: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#    {5.5: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'extras': {'noballs': 1},
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {5.6: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {5.7: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {6.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {6.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {6.3: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {6.4: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {6.5: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {6.6: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {7.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {7.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'extras': {'noballs': 1},
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 4, 'extras': 1, 'total': 5}}},
#    {7.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {7.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'V Sehwag',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {7.5: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {7.6: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {7.7: {'batsman': 'V Sehwag',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {8.1: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {8.2: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {8.3: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {8.4: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {8.5: {'batsman': 'V Sehwag',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['DE Bollinger'],
#       'kind': 'caught',
#       'player_out': 'V Sehwag'}}},
#    {8.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {9.1: {'batsman': 'G Gambhir',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {9.2: {'batsman': 'G Gambhir',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {9.3: {'batsman': 'G Gambhir',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {9.4: {'batsman': 'G Gambhir',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {9.5: {'batsman': 'G Gambhir',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {9.6: {'batsman': 'G Gambhir',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {10.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {10.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {10.3: {'batsman': 'G Gambhir',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {10.4: {'batsman': 'G Gambhir',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {10.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {10.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {11.1: {'batsman': 'G Gambhir',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {11.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {11.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {11.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {11.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {11.6: {'batsman': 'G Gambhir',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {12.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {12.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {12.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {12.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {12.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {12.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'G Gambhir',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {13.1: {'batsman': 'G Gambhir',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {13.2: {'batsman': 'G Gambhir',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {13.3: {'batsman': 'G Gambhir',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['BW Hilfenhaus'],
#       'kind': 'caught',
#       'player_out': 'G Gambhir'}}},
#    {13.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {13.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {13.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {14.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {14.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {14.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {14.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {14.5: {'batsman': 'Yuvraj Singh',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {14.6: {'batsman': 'Yuvraj Singh',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {15.1: {'batsman': 'Yuvraj Singh',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {15.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {15.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {15.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {15.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {15.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {16.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {16.2: {'batsman': 'Yuvraj Singh',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {16.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {16.4: {'batsman': 'Yuvraj Singh',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {16.5: {'batsman': 'Yuvraj Singh',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {16.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {17.1: {'batsman': 'Yuvraj Singh',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {17.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {17.3: {'batsman': 'Yuvraj Singh',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {17.4: {'batsman': 'Yuvraj Singh',
#      'bowler': 'NM Hauritz',
#      'extras': {'legbyes': 1},
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {17.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {17.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {18.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {18.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'Yuvraj Singh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {18.3: {'batsman': 'Yuvraj Singh',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'kind': 'caught and bowled', 'player_out': 'Yuvraj Singh'}}},
#    {18.4: {'batsman': 'MS Dhoni',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {18.5: {'batsman': 'MS Dhoni',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {18.6: {'batsman': 'MS Dhoni',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {19.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {19.2: {'batsman': 'MS Dhoni',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {19.3: {'batsman': 'MS Dhoni',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {19.4: {'batsman': 'MS Dhoni',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {19.5: {'batsman': 'MS Dhoni',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {19.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {20.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {20.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {20.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#    {20.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {20.5: {'batsman': 'MS Dhoni',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {20.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {21.1: {'batsman': 'MS Dhoni',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {21.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {21.3: {'batsman': 'MS Dhoni',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {21.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#    {21.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#    {21.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {22.1: {'batsman': 'MS Dhoni',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {22.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'extras': {'wides': 1},
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {22.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {22.4: {'batsman': 'MS Dhoni',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {22.5: {'batsman': 'MS Dhoni',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {22.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {22.7: {'batsman': 'MS Dhoni',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {23.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {23.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'MS Dhoni',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {23.3: {'batsman': 'MS Dhoni',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['AC Voges'],
#       'kind': 'caught',
#       'player_out': 'MS Dhoni'}}},
#    {23.4: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {23.5: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'extras': {'wides': 1},
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {23.6: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {23.7: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {24.1: {'batsman': 'SK Raina',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {24.2: {'batsman': 'SK Raina',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {24.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {24.4: {'batsman': 'SK Raina',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {24.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {24.6: {'batsman': 'SK Raina',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {25.1: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {25.2: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {25.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {25.4: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {25.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {25.6: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {26.1: {'batsman': 'SK Raina',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#    {26.2: {'batsman': 'SK Raina',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {26.3: {'batsman': 'SK Raina',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {26.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {26.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {26.6: {'batsman': 'SK Raina',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {27.1: {'batsman': 'SK Raina',
#      'bowler': 'AC Voges',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {27.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'AC Voges',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {27.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'AC Voges',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {27.4: {'batsman': 'SK Raina',
#      'bowler': 'AC Voges',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {27.5: {'batsman': 'SK Raina',
#      'bowler': 'AC Voges',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {27.6: {'batsman': 'SK Raina',
#      'bowler': 'AC Voges',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {28.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {28.2: {'batsman': 'SK Raina',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {28.3: {'batsman': 'SK Raina',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {28.4: {'batsman': 'SK Raina',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {28.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {28.6: {'batsman': 'SK Raina',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {29.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'AC Voges',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {29.2: {'batsman': 'SK Raina',
#      'bowler': 'AC Voges',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {29.3: {'batsman': 'SK Raina',
#      'bowler': 'AC Voges',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {29.4: {'batsman': 'SK Raina',
#      'bowler': 'AC Voges',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {29.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'AC Voges',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#    {29.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'AC Voges',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {30.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {30.2: {'batsman': 'SK Raina',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {30.3: {'batsman': 'SK Raina',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#    {30.4: {'batsman': 'SK Raina',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {30.5: {'batsman': 'SK Raina',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {30.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'NM Hauritz',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {31.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'AC Voges',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {31.2: {'batsman': 'SK Raina',
#      'bowler': 'AC Voges',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {31.3: {'batsman': 'SK Raina',
#      'bowler': 'AC Voges',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {31.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'AC Voges',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {31.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'AC Voges',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {31.6: {'batsman': 'SK Raina',
#      'bowler': 'AC Voges',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {32.1: {'batsman': 'SK Raina',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {32.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {32.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {32.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {32.5: {'batsman': 'SK Raina',
#      'bowler': 'BW Hilfenhaus',
#      'extras': {'wides': 1},
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {32.6: {'batsman': 'SK Raina',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {32.7: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {33.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {33.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {33.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {33.4: {'batsman': 'SK Raina',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {33.5: {'batsman': 'SK Raina',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {33.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {34.1: {'batsman': 'SK Raina',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {34.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'extras': {'legbyes': 1},
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {34.3: {'batsman': 'SK Raina',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {34.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'extras': {'wides': 1},
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {34.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {34.6: {'batsman': 'SK Raina',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {34.7: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {35.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {35.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {35.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {35.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {35.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {35.6: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {36.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {36.2: {'batsman': 'SK Raina',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {36.3: {'batsman': 'SK Raina',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {36.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {36.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {36.6: {'batsman': 'SK Raina',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {37.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {37.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {37.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {37.4: {'batsman': 'SK Raina',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {37.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {37.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {38.1: {'batsman': 'SK Raina',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {38.2: {'batsman': 'SK Raina',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {38.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {38.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {38.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {38.6: {'batsman': 'SK Raina',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {39.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {39.2: {'batsman': 'SK Raina',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {39.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {39.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {39.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {39.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'MEK Hussey',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {40.1: {'batsman': 'SK Raina',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {40.2: {'batsman': 'SK Raina',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {40.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {40.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {40.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'extras': {'wides': 1},
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {40.6: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {40.7: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {41.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SK Raina',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {41.2: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {41.3: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#    {41.4: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {41.5: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {41.6: {'batsman': 'SK Raina',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {42.1: {'batsman': 'SK Raina',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {42.2: {'batsman': 'SK Raina',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {42.3: {'batsman': 'SK Raina',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['GA Manou'],
#       'kind': 'caught',
#       'player_out': 'SK Raina'}}},
#    {42.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'SR Watson',
#      'non_striker': 'Harbhajan Singh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {42.5: {'batsman': 'Harbhajan Singh',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {42.6: {'batsman': 'Harbhajan Singh',
#      'bowler': 'SR Watson',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['GA Manou'],
#       'kind': 'caught',
#       'player_out': 'Harbhajan Singh'}}},
#    {43.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'RA Jadeja',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {43.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'RA Jadeja',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {43.3: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'extras': {'noballs': 1},
#      'non_striker': 'RA Jadeja',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {43.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'RA Jadeja',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {43.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'RA Jadeja',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {43.6: {'batsman': 'RA Jadeja',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {43.7: {'batsman': 'SR Tendulkar',
#      'bowler': 'BW Hilfenhaus',
#      'non_striker': 'RA Jadeja',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {44.1: {'batsman': 'RA Jadeja',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {44.2: {'batsman': 'RA Jadeja',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {44.3: {'batsman': 'RA Jadeja',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {44.4: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'RA Jadeja',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {44.5: {'batsman': 'RA Jadeja',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {44.6: {'batsman': 'RA Jadeja',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {45.1: {'batsman': 'RA Jadeja',
#      'bowler': 'CJ McKay',
#      'extras': {'legbyes': 1},
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {45.2: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'RA Jadeja',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {45.3: {'batsman': 'RA Jadeja',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {45.4: {'batsman': 'RA Jadeja',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {45.5: {'batsman': 'RA Jadeja',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {45.6: {'batsman': 'RA Jadeja',
#      'bowler': 'CJ McKay',
#      'extras': {'wides': 1},
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {45.7: {'batsman': 'RA Jadeja',
#      'bowler': 'CJ McKay',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {46.1: {'batsman': 'RA Jadeja',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {46.2: {'batsman': 'RA Jadeja',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {46.3: {'batsman': 'RA Jadeja',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {46.4: {'batsman': 'RA Jadeja',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {46.5: {'batsman': 'SR Tendulkar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'RA Jadeja',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {46.6: {'batsman': 'RA Jadeja',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'SR Tendulkar',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {47.1: {'batsman': 'SR Tendulkar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'RA Jadeja',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['NM Hauritz'],
#       'kind': 'caught',
#       'player_out': 'SR Tendulkar'}}},
#    {47.2: {'batsman': 'RA Jadeja',
#      'bowler': 'CJ McKay',
#      'extras': {'legbyes': 1},
#      'non_striker': 'P Kumar',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {47.3: {'batsman': 'P Kumar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'RA Jadeja',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {47.4: {'batsman': 'P Kumar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'RA Jadeja',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['CL White', 'CJ McKay'],
#       'kind': 'run out',
#       'player_out': 'RA Jadeja'}}},
#    {47.5: {'batsman': 'P Kumar',
#      'bowler': 'CJ McKay',
#      'non_striker': 'A Nehra',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {47.6: {'batsman': 'A Nehra',
#      'bowler': 'CJ McKay',
#      'non_striker': 'P Kumar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {48.1: {'batsman': 'A Nehra',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'P Kumar',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['MEK Hussey'],
#       'kind': 'caught',
#       'player_out': 'A Nehra'}}},
#    {48.2: {'batsman': 'P Kumar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'MM Patel',
#      'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#    {48.3: {'batsman': 'P Kumar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'MM Patel',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {48.4: {'batsman': 'P Kumar',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'MM Patel',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {48.5: {'batsman': 'P Kumar',
#      'bowler': 'DE Bollinger',
#      'extras': {'legbyes': 1},
#      'non_striker': 'MM Patel',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {48.6: {'batsman': 'MM Patel',
#      'bowler': 'DE Bollinger',
#      'non_striker': 'P Kumar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {49.1: {'batsman': 'MM Patel',
#      'bowler': 'SR Watson',
#      'non_striker': 'P Kumar',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {49.2: {'batsman': 'P Kumar',
#      'bowler': 'SR Watson',
#      'non_striker': 'MM Patel',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {49.3: {'batsman': 'MM Patel',
#      'bowler': 'SR Watson',
#      'extras': {'byes': 1},
#      'non_striker': 'P Kumar',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {49.4: {'batsman': 'P Kumar',
#      'bowler': 'SR Watson',
#      'non_striker': 'MM Patel',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1},
#      'wicket': {'fielders': ['NM Hauritz', 'GA Manou'],
#       'kind': 'run out',
#       'player_out': 'P Kumar'}}}]}}
